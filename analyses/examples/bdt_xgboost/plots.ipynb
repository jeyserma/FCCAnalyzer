# %%
import uproot
import hist
from hist import Hist
import matplotlib.pyplot as plt
import numpy as np
import mplhep as hep

# %%
f_mumu = uproot.open("/work/submit/jaeyserm/fccee/FCCAnalyzer/test_bdt.root")
h_sig = f_mumu['wzp6_ee_mumuH_ecm240/mva'].to_hist()
b_bkg = f_mumu['p8_ee_WW_mumu_ecm240/mva'].to_hist()

hep.histplot([h_sig, b_bkg], label=[r'MVA output signal', 'MVA output backgrounds'])
plt.legend()
plt.xlim(0,1)
# Out:
# (0.0, 1.0)

# %%
import uproot
import hist
from hist import Hist
import matplotlib.pyplot as plt
import numpy as np
import mplhep as hep

# %% [raw]
# First we open the ROOT file using uproot:

# %%
f_mumu = uproot.open("/work/submit/jaeyserm/fccee/FCCAnalyzer/output_z_xsec_mumu.root")
print(f_mumu.keys())
# Out:
# ['wzp6_ee_mumu_ecm91p2;1', 'wzp6_ee_mumu_ecm91p2/leps_all_p_cut0;1', 'wzp6_ee_mumu_ecm91p2/leps_all_theta_cut0;1', 'wzp6_ee_mumu_ecm91p2/leps_all_phi_cut0;1', 'wzp6_ee_mumu_ecm91p2/leps_all_q_cut0;1', 'wzp6_ee_mumu_ecm91p2/leps_all_no_cut0;1', 'wzp6_ee_mumu_ecm91p2/leps_all_reso_p_cut0;1', 'wzp6_ee_mumu_ecm91p2/leps_p_cut0;1', 'wzp6_ee_mumu_ecm91p2/leps_theta_cut0;1', 'wzp6_ee_mumu_ecm91p2/leps_phi_cut0;1', 'wzp6_ee_mumu_ecm91p2/leps_q_cut0;1', 'wzp6_ee_mumu_ecm91p2/leps_no_cut0;1', 'wzp6_ee_mumu_ecm91p2/leps_reso_p_cut0;1', 'wzp6_ee_mumu_ecm91p2/cutFlow_cut0;1', 'wzp6_ee_mumu_ecm91p2/cutFlow_cut1;1', 'wzp6_ee_mumu_ecm91p2/cutFlow_cut2;1', 'wzp6_ee_mumu_ecm91p2/cutFlow_cut3;1', 'wzp6_ee_mumu_ecm91p2/cutFlow_cut4;1', 'wzp6_ee_mumu_ecm91p2/zll_m_cut4;1', 'wzp6_ee_mumu_ecm91p2/zll_p_cut4;1', 'wzp6_ee_mumu_ecm91p2/leps_p_cut4;1', 'wzp6_ee_mumu_ecm91p2/meta;1', 'wzp6_ee_tautau_ecm91p2;1', 'wzp6_ee_tautau_ecm91p2/leps_all_p_cut0;1', 'wzp6_ee_tautau_ecm91p2/leps_all_theta_cut0;1', 'wzp6_ee_tautau_ecm91p2/leps_all_phi_cut0;1', 'wzp6_ee_tautau_ecm91p2/leps_all_q_cut0;1', 'wzp6_ee_tautau_ecm91p2/leps_all_no_cut0;1', 'wzp6_ee_tautau_ecm91p2/leps_all_reso_p_cut0;1', 'wzp6_ee_tautau_ecm91p2/leps_p_cut0;1', 'wzp6_ee_tautau_ecm91p2/leps_theta_cut0;1', 'wzp6_ee_tautau_ecm91p2/leps_phi_cut0;1', 'wzp6_ee_tautau_ecm91p2/leps_q_cut0;1', 'wzp6_ee_tautau_ecm91p2/leps_no_cut0;1', 'wzp6_ee_tautau_ecm91p2/leps_reso_p_cut0;1', 'wzp6_ee_tautau_ecm91p2/cutFlow_cut0;1', 'wzp6_ee_tautau_ecm91p2/cutFlow_cut1;1', 'wzp6_ee_tautau_ecm91p2/cutFlow_cut2;1', 'wzp6_ee_tautau_ecm91p2/cutFlow_cut3;1', 'wzp6_ee_tautau_ecm91p2/cutFlow_cut4;1', 'wzp6_ee_tautau_ecm91p2/zll_m_cut4;1', 'wzp6_ee_tautau_ecm91p2/zll_p_cut4;1', 'wzp6_ee_tautau_ecm91p2/leps_p_cut4;1', 'wzp6_ee_tautau_ecm91p2/meta;1', 'wzp6_ee_qq_ecm91p2;1', 'wzp6_ee_qq_ecm91p2/leps_all_p_cut0;1', 'wzp6_ee_qq_ecm91p2/leps_all_theta_cut0;1', 'wzp6_ee_qq_ecm91p2/leps_all_phi_cut0;1', 'wzp6_ee_qq_ecm91p2/leps_all_q_cut0;1', 'wzp6_ee_qq_ecm91p2/leps_all_no_cut0;1', 'wzp6_ee_qq_ecm91p2/leps_all_reso_p_cut0;1', 'wzp6_ee_qq_ecm91p2/leps_p_cut0;1', 'wzp6_ee_qq_ecm91p2/leps_theta_cut0;1', 'wzp6_ee_qq_ecm91p2/leps_phi_cut0;1', 'wzp6_ee_qq_ecm91p2/leps_q_cut0;1', 'wzp6_ee_qq_ecm91p2/leps_no_cut0;1', 'wzp6_ee_qq_ecm91p2/leps_reso_p_cut0;1', 'wzp6_ee_qq_ecm91p2/cutFlow_cut0;1', 'wzp6_ee_qq_ecm91p2/cutFlow_cut1;1', 'wzp6_ee_qq_ecm91p2/cutFlow_cut2;1', 'wzp6_ee_qq_ecm91p2/cutFlow_cut3;1', 'wzp6_ee_qq_ecm91p2/cutFlow_cut4;1', 'wzp6_ee_qq_ecm91p2/zll_m_cut4;1', 'wzp6_ee_qq_ecm91p2/zll_p_cut4;1', 'wzp6_ee_qq_ecm91p2/leps_p_cut4;1', 'wzp6_ee_qq_ecm91p2/meta;1']

# %% [markdown]
# The histograms are saved as `process_name/histogram_name`. We will now plot the Z peak after all the cuts (stored in `zll_m_cut4`) for the main `wzp6_ee_mumu_ecm91p2` process:

# %%
z_mumu = f_mumu['wzp6_ee_mumu_ecm91p2/zll_m_cut4'].to_hist()
z_mumu = z_mumu[::2j] # rebin with factor of 2

# %%
hep.histplot([z_mumu], label=[r'Z($\mu\mu$)'])
plt.legend()
plt.xlim(80,100)
plt.yscale("log")

# %% [markdown]
# To know the number of events in the histogram, we use the `.sum()` function. It returns an object containing two values: `.value` and `.variance`.

# %%
n_events_mumu = z_mumu.sum()
print("Total number of events:",n_events_mumu.value)
# Out:
# Total number of events: 247095362270.862

# %% [markdown]
# Let's get some backgrounds as well, for now we'll consider tau (`wzp6_ee_tautau_ecm91p2`) and the hadronic final states (`wzp6_ee_qq_ecm91p2`):

# %%
z_tautau = f_mumu['wzp6_ee_tautau_ecm91p2/zll_m_cut4'].to_hist()
z_tautau = z_tautau[::2j]
z_qq = f_mumu['wzp6_ee_qq_ecm91p2/zll_m_cut4'].to_hist()
z_qq = z_qq[::2j]

# %% [markdown]
# And let's plot them stacked:

# %%
hep.histplot([z_tautau, z_qq, z_mumu], label=[r'Z($\tau\tau$)', r'Z(qq)', r'Z($\mu\mu$)'], stack=True)
plt.legend()
plt.xlim(20,100)
plt.yscale("log")
# Out:
# /work/submit/submit-software/conda/envs/fcc-ee/lib/python3.10/site-packages/mplhep/error_estimation.py:49: RuntimeWarning: divide by zero encountered in divide
#   counts = sumw / scale

# %% [markdown]
# Now let's plot the Z peak for the different decay modes (di-muon, di-electron and hadronic):

# %%
f_ee = uproot.open("/work/submit/jaeyserm/fccee/FCCAnalyzer/output_z_xsec_ee.root")
f_qq = uproot.open("/work/submit/jaeyserm/fccee/FCCAnalyzer/output_z_xsec_qq.root")
z_ee = f_ee['wzp6_ee_ee_Mee_5_150_ecm91p2/zll_m_cut4'].to_hist()
z_ee = z_ee[::2j]
z_qq = f_qq['wzp6_ee_qq_ecm91p2/dijet_m'].to_hist()
z_qq = z_qq[::2j]
hep.histplot([z_mumu, z_ee, z_qq], label=[r'Z($\mu\mu$)', r'Z(ee)', r'Z(qq)'])
#hep.histplot([z_qq], label=[r'Z(qq)'])
plt.legend()
plt.xlim(80,100)
plt.yscale("log")
